# %% [markdown]
# # <center>Electiva Aprendizaje automático</center>
#
# # <center>Maestría en Gestión de Tecnologías de Información y Conocimiento</center>
#
# # <center>Facultad de Ingeniería</center>
# # <center>Universidad de Nariño</center>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
datos=pd.read_csv("./Sick_pacientes.txt",sep=";")
datos.head(20)
# Out:
#     caso  edad genero depresion embarazada cirugía_de_tiroides  nivel_TSH  \
# 0      1    56      F        NO         NO                  NO      1.900
# 1      2    51      F        NO         NO                  NO      0.250
# 2      3    50      F        NO         NO                  NO      2.000
# 3      4    73      M        NO         NO                  NO      1.800
# 4      5    56      F        NO         NO                  NO      3.774
# 5      6    44      M        NO         NO                  NO      1.900
# 6      7    24      F        NO         NO                  NO      1.700
# 7      8    40      M        NO         NO                  NO      0.250
# 8      9    81      M        NO         NO                  NO      1.300
# 9     10    53      F        NO         NO                  NO      0.850
# 10    11    36      M        NO         NO                  NO      1.700
# 11    12    35      F        NO         NO                  NO      1.200
# ...

# %% [markdown]
# 1.Clasificar las variables de la base.

# %%
datos.dtypes
# Out:
# caso                     int64
# edad                     int64
# genero                  object
# depresion               object
# embarazada              object
# cirugía_de_tiroides     object
# nivel_TSH              float64
# nivel_T3               float64
# nivel_TT4              float64
# nivel_T4U              float64
# nivel_FTI              float64
# clase                    int64
# dtype: object

# %% [markdown]
# 2.Construir la tabla de frecuencias y un diagrama de barras de las variables categóricas.

# %%
print("\n",datos.groupby('genero').count()['caso'])
print("\n",datos.groupby('depresion').count()['caso'])
print("\n",datos.groupby('embarazada').count()['caso'])
print("\n",datos.groupby('clase').count()['caso'])
print("\n",datos.groupby(['embarazada','genero']).count()['caso'])
# Out:
#  genero
# F    634
# M    321
# Name: caso, dtype: int64
#
#  depresion
# NO    921
# SI     34
# Name: caso, dtype: int64
#
#  embarazada
# NO    940
# SI     15
# Name: caso, dtype: int64
#
#  clase
# 0    907
# 1     48
# Name: caso, dtype: int64
#
#  embarazada  genero
# NO          F         619
#             M         321
# SI          F          15
# Name: caso, dtype: int64

# %%
datos.groupby('genero').count()["caso"].plot(kind='bar',title='diagrama de barras genero')
plt.show()


datos.groupby('depresion').count()["caso"].plot(kind='bar',title='diagrama de barras pacientes con depresión')
plt.show()

datos.groupby('embarazada').count()["caso"].plot(kind='bar',title='diagrama de barras pacientes embarazadas')
plt.show()

datos.groupby('clase').count()["caso"].plot(kind='bar',title='diagrama de barras pacientes enfermos')
# Out:
# <AxesSubplot:title={'center':'diagrama de barras pacientes enfermos'}, xlabel='clase'>

# %% [markdown]
# 3.Calcular las medidas de resumen de las variables cuantitativas.

# %%
datos.drop(columns=['caso']).describe()
# Out:
#              edad   nivel_TSH    nivel_T3   nivel_TT4   nivel_T4U   nivel_FTI  \
# count  955.000000  955.000000  955.000000  955.000000  955.000000  955.000000
# mean    51.794764    3.773681    2.039007  108.330639    0.992342  110.891749
# std     22.972953   12.110847    0.714392   33.916230    0.189764   30.195374
# min      1.000000    0.005000    0.100000    4.800000    0.310000    5.400000
# 25%     36.000000    0.530000    1.700000   88.000000    0.890000   94.000000
# 50%     54.000000    1.500000    2.044000  107.000000    0.992300  110.890000
# 75%     67.000000    3.500000    2.200000  123.000000    1.070000  123.000000
# max    455.000000  183.000000    7.000000  430.000000    2.120000  395.000000
#
#             clase
# count  955.000000
# mean     0.050262
# std      0.218599
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %% [markdown]
# 4.¿Cuáles de las variables le parecen simétricas a partir de estos resúmenes? Confirme estas observaciones mediante un boxplot.

# %%
green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Boxplot edad')
fig3.set_size_inches(10,5)
ax3.boxplot(datos.edad, flierprops=green_diamond,widths=0.3,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13e06b2b5c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x13e06b48e48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x13e061d8cc8>],
#  'medians': [<matplotlib.lines.Line2D at 0x13e06b50ac8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13e06b48648>],
#  'means': []}

# %%
green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Boxplot nivel TSH')
fig3.set_size_inches(10,5)
ax3.boxplot(datos.nivel_TSH, flierprops=green_diamond,widths=0.3,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13e06c0ba08>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x13e07c21988>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x13e06c17e88>],
#  'medians': [<matplotlib.lines.Line2D at 0x13e07c00d48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13e07c00e08>],
#  'means': []}

# %%
green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Boxplot nivel T3')
fig3.set_size_inches(10,5)
ax3.boxplot(datos.nivel_T3, flierprops=green_diamond,widths=0.3,vert=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13e07c50448>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x13e07c6db08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x13e07c5ca48>],
#  'medians': [<matplotlib.lines.Line2D at 0x13e07c74ec8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13e07c74f08>],
#  'means': []}

# %%
green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Boxplot nivel TT4')
fig3.set_size_inches(10,5)
ax3.boxplot(datos.nivel_TT4, flierprops=green_diamond,widths=0.3,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13e07cbcc48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x13e07cded08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x13e07cc8a08>],
#  'medians': [<matplotlib.lines.Line2D at 0x13e07ce1a48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13e07ce9d48>],
#  'means': []}

# %%
green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Boxplot nivel T4U')
fig3.set_size_inches(10,5)
ax3.boxplot(datos.nivel_T4U, flierprops=green_diamond,widths=0.3,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13e07d29488>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x13e07d47fc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x13e07d36988>],
#  'medians': [<matplotlib.lines.Line2D at 0x13e07d4fe08>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13e07d4fe48>],
#  'means': []}

# %%
green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Boxplot nivel FTI')
fig3.set_size_inches(10,5)
ax3.boxplot(datos.nivel_FTI, flierprops=green_diamond,widths=0.3,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13e07d8ba48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x13e07db8e88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x13e07d8b408>],
#  'medians': [<matplotlib.lines.Line2D at 0x13e07dbcc88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13e07dc4f88>],
#  'means': []}

# %% [markdown]
# 5.Detectar presencia de valores salvajes moderados y severos en cada una de las variables cuantitativas.

# %%
def detecta_oulier(df,variable,registro,clase):
    q3=df[variable].quantile(0.75)
    q1=df[variable].quantile(0.25)

    di=q3-q1

    outsupModerado1=q3+1.5*di
    outsupModerado2=q3+3*di

    outinfModerado1=q1-(1.5*di)
    outinfModerado2=q1-(3*di)

    filtrosup1=df[variable]>=outsupModerado1
    filtrosup2=df[variable]<=outsupModerado2
    
    filtroinf1=df[variable]<=outinfModerado1
    filtroinf2=df[variable]>=outinfModerado2

    filtrosup3=df[variable]>outsupModerado2
    filtroinf3=df[variable]<outinfModerado2

    if len(df[filtrosup1 & filtrosup2])>0:
        print("outliers moderados q3:",len(df[filtrosup1 & filtrosup2]))
        display(df[filtrosup1 & filtrosup2][[variable,registro,clase]])
    if len(df[filtrosup3])>0:
        print("outliers severos q3:",len(df[filtrosup3]))
        display(df[filtrosup3][[variable,registro,clase]])
    if len(df[filtroinf1 & filtroinf2])>0:
        print("outliers moderados q1:", len(df[filtroinf1 & filtroinf2]))
        display(df[filtroinf1 & filtroinf2][[variable,registro,clase]])
    if len(df[filtroinf3]):
        print("outliers severos q1:",len(df[filtroinf3]))
        display(df[filtroinf3][[variable,registro,clase]])
    return(df[filtrosup1 & filtrosup2],df[filtrosup3],
           df[filtroinf1 & filtroinf2],df[filtroinf3]
          )

# %%
print("Edad")    
sevq3,modq3,modq1,sevq3=detecta_oulier(datos,'edad','caso','clase')
# Out:
# Edad
# outliers severos q3: 1
#      edad  caso  clase
# 237   455   262      0

# %%
print("nivel_TSH")    
sevq3,modq3,modq1,sevq3=detecta_oulier(datos,'nivel_TSH','caso','clase')
# Out:
# nivel_TSH
# outliers moderados q3: 31
#      nivel_TSH  caso  clase
# 64         8.3    68      0
# 73        11.0    82      0
# 74         9.4    83      0
# 96         8.6   105      0
# 108       12.0   117      0
# 109        9.0   118      0
# 118        8.2   127      0
# 133       10.0   144      0
# 148        9.1   161      0
# 149       11.4   162      0
# 156        9.4   175      0
# 217       11.0   236      0
# 264        9.6   290      0
# 305        8.9   337      0
# 321       12.0   354      0
# 344        8.1   377      0
# 440       11.0   482      0
# 441       11.0   483      0
# 447        9.2   489      0
# 521        9.4   574      0
# 562       12.0   619      0
# 568       12.0   625      0
# 588       12.0   645      0
# 591        9.1   653      0
# 613       12.0   677      0
# 732        9.7   801      0
# 829       11.0   907      0
# 837        8.5   915      0
# 885       12.0   969      0
# 899        9.3   983      0
# 948       11.0   735      1
# ...

# %%
print("nivel_T3")    
sevq3,modq3,modq1,sevq3=detecta_oulier(datos,'nivel_T3','caso','clase')
# Out:
# nivel_T3
# outliers moderados q3: 34
#      nivel_T3  caso  clase
# 56        3.2    60      0
# 91        3.3   100      0
# 109       3.1   118      0
# 121       3.6   131      0
# 131       3.1   142      0
# 176       3.2   195      0
# 200       3.5   219      0
# 206       3.5   225      0
# 291       3.0   318      0
# 340       3.0   373      0
# 343       3.4   376      0
# 356       3.1   390      0
# 416       3.1   454      0
# 418       3.4   456      0
# 438       3.1   480      0
# 475       3.6   518      0
# 507       3.0   552      0
# 540       3.4   593      0
# 554       3.4   608      0
# 559       3.0   614      0
# 578       3.3   635      0
# 582       3.2   639      0
# 584       3.6   641      0
# 586       3.0   643      0
# 620       3.0   684      0
# 621       3.7   685      0
# 665       3.2   729      0
# 715       3.5   784      0
# 717       3.1   786      0
# 771       3.4   846      0
# 846       3.1   926      0
# 859       3.1   940      0
# ...

# %%
print("nivel_TT4")    
sevq3,modq3,modq1,sevq3=detecta_oulier(datos,'nivel_TT4','caso','clase')
# Out:
# nivel_TT4
# outliers moderados q3: 27
#      nivel_TT4  caso  clase
# 144      177.0   157      0
# 200      194.0   219      0
# 212      198.0   231      0
# 223      192.0   243      0
# 273      205.0   300      0
# 356      206.0   390      0
# 362      182.0   399      0
# 387      176.0   425      0
# 391      189.0   429      0
# 426      191.0   468      0
# 450      180.0   492      0
# 496      213.0   541      0
# 554      189.0   608      0
# 582      187.0   639      0
# 584      184.0   641      0
# 596      184.0   659      0
# 597      193.0   660      0
# 615      182.0   679      0
# 621      182.0   685      0
# 715      217.0   784      0
# 718      179.0   787      0
# 759      198.0   834      0
# 798      187.0   875      0
# 818      214.0   896      0
# 900      189.0   984      0
# 902      213.0   986      0
# 947      180.0   734      1
# outliers severos q3: 7
#      nivel_TT4  caso  clase
# 123      289.0   133      0
# 150      239.0   163      0
# ...

# %%
print("nivel_T4U")    
sevq3,modq3,modq1,sevq3=detecta_oulier(datos,'nivel_T4U','caso','clase')
# Out:
# nivel_T4U
# outliers moderados q3: 28
#      nivel_T4U  caso  clase
# 42        1.46    44      0
# 98        1.35   107      0
# 119       1.39   128      0
# 133       1.39   144      0
# 144       1.46   157      0
# 219       1.34   239      0
# 223       1.44   243      0
# 236       1.39   261      0
# 282       1.40   309      0
# 356       1.59   390      0
# 381       1.57   419      0
# 438       1.49   480      0
# 554       1.35   608      0
# 578       1.46   635      0
# 583       1.58   640      0
# 613       1.37   677      0
# 615       1.37   679      0
# 636       1.38   700      0
# 690       1.50   759      0
# 700       1.36   769      0
# 718       1.36   787      0
# 723       1.42   792      0
# 753       1.38   828      0
# 758       1.50   833      0
# 777       1.51   852      0
# 799       1.57   876      0
# 842       1.38   922      0
# 843       1.55   923      0
# outliers severos q3: 16
#      nivel_T4U  caso  clase
# 56        1.83    60      0
# ...

# %%
print("nivel_FTI")    
sevq3,modq3,modq1,sevq3=detecta_oulier(datos,'nivel_FTI','caso','clase')
# Out:
# nivel_FTI
# outliers moderados q3: 25
#      nivel_FTI  caso  clase
# 20       168.0    22      0
# 95       206.0   104      0
# 106      205.0   115      0
# 127      170.0   138      0
# 206      173.0   225      0
# 209      176.0   228      0
# 289      168.0   316      0
# 292      172.0   324      0
# 351      189.0   385      0
# 391      176.0   429      0
# 416      177.0   454      0
# 418      185.0   456      0
# 426      194.0   468      0
# 450      172.0   492      0
# 458      204.0   500      0
# 475      171.0   518      0
# 481      188.0   524      0
# 594      172.0   656      0
# 629      173.0   693      0
# 648      167.0   712      0
# 737      183.0   806      0
# 746      171.0   815      0
# 755      204.0   830      0
# 941      174.0   648      1
# 949      207.0   736      1
# outliers severos q3: 11
#      nivel_FTI  caso  clase
# 200      215.0   219      0
# 354      395.0   388      0
# 412      218.0   450      0
# 526      216.0   579      0
# ...

# %% [markdown]
# 6.Realizar un boxplot comparativo para cada una de estas variables particionando por la clase. ¿Le parece que alguna de estas variables está relacionada con la enfermedad, es decir que toma valores muy distintos en ambos grupos? Analizar en todos los casos la presencia de outliers.

# %%
data = [datos[datos['clase']==0].edad, datos[datos['clase']==1].edad]
fig7, ax7 = plt.subplots()
ax7.set_title('boxplot comparativo edad')
ax7.boxplot(data)
plt.show()

# %%
data = [datos[datos['clase']==0].nivel_TSH, datos[datos['clase']==1].edad]
fig7, ax7 = plt.subplots()
ax7.set_title('boxplot comparativo nivel_TSH')
ax7.boxplot(data)
plt.show()

# %%
data = [datos[datos['clase']==0].nivel_T3, datos[datos['clase']==1].edad]
fig7, ax7 = plt.subplots()
ax7.set_title('boxplot comparativo nivel_T3')
ax7.boxplot(data)
plt.show()

# %%
data = [datos[datos['clase']==0].nivel_TT4, datos[datos['clase']==1].edad]
fig7, ax7 = plt.subplots()
ax7.set_title('boxplot comparativo nivel_TT4')
ax7.boxplot(data)
plt.show()

# %%
#edad	nivel_TSH	nivel_T3	nivel_TT4	nivel_T4U	nivel_FTI	clase
data = [datos[datos['clase']==0].nivel_T4U, datos[datos['clase']==1].edad]
fig7, ax7 = plt.subplots()
ax7.set_title('boxplot comparativo nivel_T4U')
ax7.boxplot(data)
plt.show()

# %%
data = [datos[datos['clase']==0].nivel_FTI, datos[datos['clase']==1].edad]
fig7, ax7 = plt.subplots()
ax7.set_title('boxplot comparativo nivel_FTI')
ax7.boxplot(data)
plt.show()

# %% [markdown]
# 7.Hallar las matrices de varianzas y covarianzas y de correlaciones.

# %%
datos.drop(columns=['caso']).cov()
# Out:
#                  edad   nivel_TSH   nivel_T3    nivel_TT4  nivel_T4U  \
# edad       527.756576   -4.546745  -3.181298   -22.045582  -0.583977
# nivel_TSH   -4.546745  146.672617  -1.664949  -129.365019   0.223349
# nivel_T3    -3.181298   -1.664949   0.510356    11.750985   0.058197
# nivel_TT4  -22.045582 -129.365019  11.750985  1150.310629   2.855427
# nivel_T4U   -0.583977    0.223349   0.058197     2.855427   0.036010
# nivel_FTI   39.685726 -127.945410   5.671876   764.893706  -1.102207
# clase        0.513471   -0.054352  -0.055946    -0.651856  -0.007998
#
#             nivel_FTI     clase
# edad        39.685726  0.513471
# nivel_TSH -127.945410 -0.054352
# nivel_T3     5.671876 -0.055946
# nivel_TT4  764.893706 -0.651856
# nivel_T4U   -1.102207 -0.007998
# nivel_FTI  911.760633  0.181432
# clase        0.181432  0.047786

# %%
datos.drop(columns=['caso']).corr()
# Out:
#                edad  nivel_TSH  nivel_T3  nivel_TT4  nivel_T4U  nivel_FTI  \
# edad       1.000000  -0.016342 -0.193843  -0.028294  -0.133957   0.057211
# nivel_TSH -0.016342   1.000000 -0.192438  -0.314945   0.097185  -0.349872
# nivel_T3  -0.193843  -0.192438  1.000000   0.484987   0.429289   0.262936
# nivel_TT4 -0.028294  -0.314945  0.484987   1.000000   0.443660   0.746884
# nivel_T4U -0.133957   0.097185  0.429289   0.443660   1.000000  -0.192358
# nivel_FTI  0.057211  -0.349872  0.262936   0.746884  -0.192358   1.000000
# clase      0.102247  -0.020530 -0.358247  -0.087922  -0.192806   0.027487
#
#               clase
# edad       0.102247
# nivel_TSH -0.020530
# nivel_T3  -0.358247
# nivel_TT4 -0.087922
# nivel_T4U -0.192806
# nivel_FTI  0.027487
# clase      1.000000

# %% [markdown]
# 8. Aplicar la estandarización z-score y calcular la matriz de varianzas y covarianzas.

# %%
def escala_zscore(X,clase):
    df=pd.DataFrame()
    for c in X.columns:
        if X[c].dtype!='object' and c!=clase:
            df[c]=(X[c]-X[c].mean())/(X[c].std())
        else :
            df[c]=(X[c])
    return df

X_escala=escala_zscore(datos,'clase')
X_escala.head()
# Out:
#        caso      edad genero depresion embarazada cirugía_de_tiroides  \
# 0 -1.729321  0.183052      F        NO         NO                  NO
# 1 -1.725814 -0.034596      F        NO         NO                  NO
# 2 -1.722308 -0.078125      F        NO         NO                  NO
# 3 -1.718801  0.923052      M        NO         NO                  NO
# 4 -1.715295  0.183052      F        NO         NO                  NO
#
#    nivel_TSH  nivel_T3  nivel_TT4  nivel_T4U  nivel_FTI  clase
# 0  -0.154711  0.006989   0.609424   0.303842   0.400997      0
# 1  -0.290952 -0.194581  -0.216140   0.461934  -0.559415      0
# 2  -0.146454  0.645294   0.727362   0.461934   0.400997      0
# 3  -0.162968  0.085377  -0.157171  -0.381221   0.036703      0
# 4   0.000026  2.605002   0.963237   0.672722   0.500350      0

# %%
X_escala.drop(columns=['caso','clase']).cov()
# Out:
#                edad  nivel_TSH  nivel_T3  nivel_TT4  nivel_T4U  nivel_FTI
# edad       1.000000  -0.016342 -0.193843  -0.028294  -0.133957   0.057211
# nivel_TSH -0.016342   1.000000 -0.192438  -0.314945   0.097185  -0.349872
# nivel_T3  -0.193843  -0.192438  1.000000   0.484987   0.429289   0.262936
# nivel_TT4 -0.028294  -0.314945  0.484987   1.000000   0.443660   0.746884
# nivel_T4U -0.133957   0.097185  0.429289   0.443660   1.000000  -0.192358
# nivel_FTI  0.057211  -0.349872  0.262936   0.746884  -0.192358   1.000000

# %% [markdown]
# 9. Graficar un dispersograma .

# %%
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
sns.pairplot(datos.drop(columns=['caso']),hue="clase")
plt.show()

# %%
p1 = sns.heatmap(datos[['edad','nivel_TSH','nivel_T3','nivel_TT4','nivel_T4U','nivel_FTI']].corr(),annot=True, annot_kws={"size": 7},
                cmap='PuOr')

# %%
p1 = sns.heatmap(X_escala[['edad','nivel_TSH','nivel_T3','nivel_TT4','nivel_T4U','nivel_FTI']].cov(),annot=True, annot_kws={"size": 7},
                cmap='PuOr')
